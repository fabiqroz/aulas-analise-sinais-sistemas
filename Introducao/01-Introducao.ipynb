# %% [markdown]
# <h1><center>Sinais e Sistemas - Conceitos Básicos</center></h1>

# %% [markdown]
# *Fonte: Sinais e sistemas - 2ª Edição / Alan V. Oppenheim, Alan S. Willsky e S. Hamid Nawab*

# %% [markdown]
# <a id="0"></a> <br>
#
# # Conteúdo da aula
# 1. [Introdução](#chapter1)
#     1. [O que são sinais e sistemas?](#section_1_1)
#     2. [Exemplos de sinais e sistemas](#section_1_2)
#  2. [Classificação de sinais](#chapter2)
#     1. [Sinais contínuos e discretos no tempo](#section_2_1)
#        1. [Notações para sinais contínuos e discretos no tempo](#section_2_1_1)
#        2. [Criando e manipulando funções no python](#section_2_1_2)

# %% [markdown]
# # Introdução <a class="anchor" id="chapter1"></a>
#
#
#
# Noções intuitivas de sinais e sistemas podem ser vistas em uma <b>ampla variedade de contextos</b>.
#
# A ideias e técnicas associadas a conceitos de sinais e sistemas desempenham um papel importante em áreas diversificadas da ciência e tecnologia, como comunicações, aeronáutica e astronáutica, projeto de circuitos, acústica, sismologia, engenharia biomédica, sistemas de geração e distribuição de energia, controle de processos químicos, processamento de voz e imagens, dentre outras áreas.
#
# Apresentaremos conceitos básicos sobre sinais e sistemas introduzindo sua descrição matemática e suas representações.

# %% [markdown]
# ## O que são sinais e sistemas?? <a class="anchor" id="section_1_1"></a>
#
# Basicamente,
# 1. Sinais são **mapeamentos de uma ou mais variáveis independentes** que **contêm informações sobre o comportamento ou natureza
# de algum fenômeno**.
# 2. **Sistemas respondem a sinais** em particular, **produzindo outros sinais ou algum comportamento** desejado.
#
# <img src ="../figs/sinais_sistemas.jpeg"  width = "600">

# %% [markdown]
# ## Exemplos de sinais e sistemas <a class="anchor" id="section_1_2"></a>
#
# 🟢 Tensões e correntes como uma função do tempo em um circuito elétrico são exemplos de sinais, e um circuito por si só é um exemplo de um sistema, que, nesse caso, responde a tensões e correntes aplicadas.

# %% [markdown]
# <img src = "https://drive.google.com/uc?id=1g7oto5Sp42g17s8qQsUmsGFcfDyefKfs" width = "500">

# %% [markdown]
# 🟢 Quando um motorista de automóvel pressiona o pedal do acelerador, o veículo responde aumentando a velocidade. Nesse caso, o sistema é o automóvel, a pressão sobre o pedal do acelerador é a entrada do sistema e a velocidade do veículo é a resposta.

# %% [markdown]
# <img src = "https://drive.google.com/uc?id=1nM7xupr6jA_z7QcxPmL9IQInbQ2HMTUS" width = "500">

# %% [markdown]
# 🟢 Uma gravação de um sinal de fala, obtido com o uso de um microfone para detectar as variações na pressão acústica, que depois são convertidas em um sinal elétrico.

# %% [markdown]
# <img src = "https://drive.google.com/uc?id=14x1otD53cUQo3EAHC9Lfg8Yxm6WScFcb" width = "600">

# %% [markdown]
# 🟢 Um programa de computador para o diagnóstico automatizado de eletrocardiogramas pode ser visto como um sistema que tem como sua entrada um eletrocardiograma digitalizado e que produz estimativas de parâmetros, como a frequência cardíaca, como saídas.
#
# 🟢 Um braço de robô é um sistema cujos movimentos são a resposta a entradas de controle
#
# 🟢 Uma câmera é um sistema que recebe luz de diversas fontes, inclusive refletidas de objetos, e produz uma fotografia.

# %% [markdown]
# <img src = "https://drive.google.com/uc?id=1wwEBbYnVS6CBsns9GlLkMCwQhR_7ytYd" width = "500">

# %% [markdown]
# # Classificação de Sinais <a class="anchor" id="chapter2"></a>
#
# 🟣 Sinais contínuos e discretos
#
# 🟣 Sinais analógicos e digitais
#
# 🟣 Sinais periódicos e não periódicos
#
# 🟣 Sinais determinísticos e probabilísticos

# %% [markdown]
# ## Notações matemáticas úteis <a class="anchor" id="section_2_1_1"></a>

# %% [markdown]
# * Conjuntos serão definidos por notação apropriada (letras maiúsculas simpples) e seus elementos são delimitados por chaves ou paranteses
#
#   Ex.: $A = [a_1 ... a_n) = \{a_i \in \mathbb{Z} : a_1 \leq a_i < a_n\} = \{a_1, a_2, ..., a_{n-1}\}$
#
# * Um mapeamento é um relacionamento envolvendo dois conjuntos que associa cada elemento de um conjunto, denominado domínio, a um
# elemento do outro conjunto, chamado contradomínio. A notação $f:A \rightarrow  B$ denota um mapeamento $f$ cujo domínio é o
# conjunto $A$ e cujo contradomínio é o conjunto $B$. Mapeamentos serão sempre definidas por letras minúsculas simples.
#
#   Ex.: $A=\{1,2,3,4\}$ e $A=\{0,1,2,3\}$ Seja, $f:A \rightarrow  B$, então:
#   $f(t) = \begin{cases}0 \;\; t \in \{1,2\} \\ 1 \;\; t = 5 \\ 2 \;\; t = 3 \end{cases}$
#
# * Uma função é um mapeamento em que o domínio é um conjunto de natureza contínua, como números reais, números complexos ou um subconjunto de qualquer um deles. Na prática, o contradomínio normalmente é composto por números reais ou números complexos. As funções também são comumente chamadas de **sinais de tempo contínuo (CT)**. Aqui, nos concentramos principalmente em
# funções de uma única variável independente (ou seja, funções unidimensionais). A função trigonométrica seno é um exemplo de função:
#
#   $f: \mathbb{R} \rightarrow \mathbb{R}$, tal que $f(t) = \sin(t)$
#
# * Uma sequência é um mapeamento em que o domínio é um conjunto de natureza discreta, como os inteiros ou um subconjunto deles.
# Na prática, o contradomínio normalmente é composto por números reais ou números complexos. As sequências também são comumente
# chamados de **sinais de tempo discreto (DT)**. Aqui, nos concentramos principalmente em sequências com uma única variável independente
# (ou seja, sequências unidimensionais). A sequência $1^2, 2^2, 3^2, 4^2,...$ de quadrados perfeitos é um exemplo de sequência. Isto
# associa cada número inteiro (estritamente) positivo $n$ ao número inteiro $n^2$ . Neste caso, o domínio e o contradomínio são os positivos inteiros e podemos expressar a sequencia como:
#
#   $f: \mathbb{Z} \rightarrow \mathbb{Z}$, tal que $f[n] = n^2$

# %% [markdown]
# ## Sinais contínuos e discretos no tempo <a class="anchor" id="section_2_1"></a>

# %% [markdown]
# No caso dos sinais de tempo contínuo, a **variável independente é contínua** e, portanto, esses sinais são
# definidos em um conjunto contínuo de valores da variável independente.
#
# Em contrapartida, os sinais de tempo discreto são definidos somente em instantes discretos, ou seja, a **variável independente assume apenas um conjunto discreto de valores**.
#
# Exemplos:
#
# 1. Um sinal de fala em função do tempo e a pressão atmosférica em função da altitude são exemplos de sinais cuja variável independente é contínua.
# 2. O índice semanal Dow-Jones da Bolsa de Valores de Nova York é um exemplo de sinal cuja variável independente é  discreta.

# %% [markdown]
# <img src = "https://drive.google.com/uc?id=1TmUzTDF3Pk7pzv73UoyiAZ7YWUQ0WFpT" width = "300">
#
# <img src = "https://drive.google.com/uc?id=1XqFjMt_At6wry6W_Kx-lLW-qbCcmWZJQ" width = "500">

# %% [markdown]
# ### Amostragem

# %% [markdown]
# Um sinal de tempo discreto $x[n]$ pode representar um fenômeno para o qual a variável independente é inerentemente discreta. Por outro lado, **uma classe muito importante de sinais de tempo discreto decorre da amostragem de sinais de tempo contínuo**. Nesse caso, o sinal de tempo discreto $x[n]$ representa amostras sucessivas de um fenômeno para o qual a variável independente é contínua.
#
# <img src = "../figs/continuous_vs_sampling.jpeg" width = "500">
#
# Um exemplo de um sinal inerentemente discreto  correspondente ao mercado de ações Dow Jones Industrial Average
# índice (que é definido apenas em intervalos diários), enquanto um exemplo de um sinal amostrado seria a versão amostrada de um (tempo contínuo) sinal de fala.

# %% [markdown]
# ## Sinais analógicos e digitais <a class="anchor" id="section_2_2"></a>

# %% [markdown]
# O conceito de tempo contínuo é geralmente confundido com o conceito de analógico. **Contudo, os dois conceitos são diferentes**. O mesmo é válido para os conceitos de tempo discreto e digital.
#
# * Os termos contínuo no tempo e discreto no tempo qualificam a natureza do sinal ao longo do eixo de tempo (eixo horizontal).
# * Os termos analógico e digital, por outro lado, qualificam a natureza da amplitude do sinal (eixo vertical).
#
# O processo de conversão de sinais contínuos em discretos se chama **Amostragem**.  Já o processo de conversão de sinais analógicos em digitais se chama **Quantização**

# %% [markdown]
# <img src = "https://drive.google.com/uc?id=12E3gZyMZK4zbUYZ9lvZLPjb9J7tg8LcL" width = "600">

# %% [markdown]
# ### Criando sinais no python <a class="anchor" id="section_2_1_2"></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# 🟣 $x(t) = t^3 - \frac{t^2}{2} - 2t$

# %%
# Taxa de amostragem do sinal que iremos gerar (discretização no tempo)
n = 50000

# Definindo a amostra no tempo
t = np.linspace(0, 10, n)

# Função que calcula o valor da amplitude do sinal para cada instante de tempo amostrado
def sinal(t):
    return np.power(t,3) - np.power(t,2)/2 - 2*t

# Vizualização
plt.plot(t, sinal(t))
plt.grid(linestyle='--')
plt.xlabel("t")
plt.ylabel("x(t)")
plt.show()

# %% [markdown]
# ## Sinais Periódicos e não-periódicos <a class="anchor" id="section_2_3"></a>

# %% [markdown]
# Um sinal $x(t)$ é dito periódico se para alguma constante positiva $T$ $$x(t) = x(t+T) \;\; \text{para todo t} $$
#
# Em outras palavras, um sinal periódico tem a propriedade de não se modificar pelo deslocamento no tempo de $T$.

# %% [markdown]
# * O menor valor de $T$ que satisfaça a equação é o **período fundamental** do sinal $x(t)$
#
# <img src = "https://drive.google.com/uc?id=1Zhew2Nh33ulnv1CYPnL6fpp_5ZuIrxOc" width = "700">

# %% [markdown]
# ### Propriedades de sinais periódicos
#
# Além do período, um sinal periódico pode ser caracterizado por outras propriedades, tais como sua frequencia, sua amplitude de pico e sua amplitude de pico a pico.

# %% [markdown]
# <img src = "../figs/ondas.jpeg" width = "700">

# %% [markdown]
# Um sinal que não começar antes de $t = 0$ é um **sinal causal**. Em outras palavras, x(t) é um sinal causal se:
#
# $x(t) = 0 \;\;\; t < 0$
#
# * Sinais Causais:
#
# <img src = "https://drive.google.com/uc?id=1p3IU03CJ6s8WxbX3SVw4Np1qgVrD7tbT" width = "600">
#
# * Sinais Não-Causais:
#
# <img src = "https://drive.google.com/uc?id=1dZ5HnL4xY0iJ9x5bc_5velqzE2H5uBQr" width = "600">

# %%
# Gera sinal causal 
def sinal_senoidal(frequencia, tempo):
    sinal = np.sin(frequencia*tempo)
    return sinal

# Taxa de amostragem do sinal que iremos gerar
n = 1000

# Período
p = 10

# Amostrando o sinal no tempo
x = np.linspace(0, 30, n)

# Definindo o período e frequencia do sinal
f = 2*np.pi/p

# Vizualização
plt.plot(x, sinal_senoidal(f,x))
plt.grid(which="both", linestyle = "--")
plt.show()

# %% [markdown]
# ## Sinais determinísticos, caóticos e estocásticos <a class="anchor" id="section_2_5"></a>
#
# 🟡 Um sinal cuja descrição física é completamente conhecida, seja na forma matemática ou na forma gráfica é um sinal determinístico.
#
# 🟡 Um sinal cujos valores não podem ser preditos precisamente, mas são conhecidos apenas em termos de uma descrição probabilística, tal como o valor médio ou valor médio quadrático, são sinais aleatórios. Neste livro, trabalharemos exclusivamente com sinais determinísticos. Os sinais aleatórios estão além do escopo dos nosssos estudos.
#
# <img src = "../figs/deterministic_stochastic.png" width = "500">
#
#
# 🟡 Um sinal cuja descrição física é completamente conhecida, mas que mudanças sutis na entrada podem trazer um comportamente imprevisível é chamado de caótico.

# %% [markdown]
# ### Sinal Estocástico

# %%
# Taxa de amostragem do sinal que iremos gerar
n = 100

# Amostrando o sinal no tempo
t = np.linspace(-100, 100, n)



# parametros do ruido
par = {'intercept':100, 'slope':0.5, 'amplitude':10}
x = par['intercept'] + par['slope']*t
x_ruido = par['intercept'] + par['slope']*t + par['amplitude']*np.random.randn(len(t))
# Vizualização
fig, ax = plt.subplots(1, 2)
ax[0].plot(t, x)
ax[0].plot(t, x_ruido, c='orange')
l = ['Sinal original', 'Sinal ruidoso']
ax[0].legend(l)

x_mat = np.column_stack( [t_high, np.ones(len(t_high))])
slope, intercept = np.linalg.lstsq(x_mat, x_high, rcond=None)[0]
ax[1].plot(t, x_ruido, c='orange')
ax[1].plot(t,  intercept + slope*t, c='red')
l = ['Sinal ruidoso', 'Sinal original estimado']
ax[1].legend(l)

plt.show()

# %% [markdown]
# ### Sinal Caótico ❤️❤️❤️❤️

# %%
def logistic_map(R, x_t, steps):
    x_t_array = np.empty(steps, dtype=np.float64)

    for i in range(steps):
        x_t_array[i] = x_t
        x_t = R*x_t*(1-x_t)

    return x_t_array

t = np.arange(80)
x_t_array = logistic_map(4, 0.2, t.size)
x_t_array_1 = logistic_map(3.99,0.2000000000000001, t.size)

fig, axs = plt.subplots(2)
fig.suptitle(r"Dynamical systems and chaos: Logistic map")
axs[0].plot(t, x_t_array, '-o', markersize = 3, linewidth = 0.5)
axs[0].plot(t, x_t_array_1, '--o', markersize = 3, linewidth = 0.5)
axs[0].set_title('Time Series for a logistic map with two different initial conditions')
axs[1].plot(t, x_t_array-x_t_array_1, '-o', color = 'green', markersize = 3, linewidth = 0.5)
axs[1].set_title('Differences between the two time series')
fig.tight_layout()
plt.show()

# %% [markdown]
# <iframe width="560" height="315" src="https://www.youtube.com/embed/05OcAXuVPXo?si=dnDwBVIl3N8MK0pM" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" allowfullscreen></iframe>

# %% [markdown]
# # Energia e potência de um sinal <a class="anchor" id="section_2_4"></a>

# %% [markdown]
# ## Tamanho de um Sinal <a class="anchor" id="section_2_4_1"></a>
#
# O tamanho de qualquer entidade é um número que indica a largura ou o comprimento da entidade. Genericamente falando, a amplitude do sinal varia com o tempo.
#
# **Como um sinal que existe em um certo intervalo de tempo com amplitude variante pode ser medido por um número que irá indicar o tamanho ou a força do sinal?**
#
# Tal medida deve considerar não apenas a **amplitude** do sinal, mas também sua **duração**.

# %% [markdown]
# ## Energia de um Sinal <a class="anchor" id="section_2_4_2"></a>
#
# Argumentando desta forma, podemos considerar a área abaixo do sinal $x(t)$ sob um determinado intervalo $[t_1, t_2]$ como uma possível medida de seu tamanho, pois a área irá considerar não somente a amplitude, mas também sua duração.
#
# $\text{Tamanho} = \int_{t_1}^{t_2} x(t)dt$

# %%
# Taxa de amostragem do sinal que iremos gerar
n = 1000

# Amostrando o sinal no tempo
t = np.linspace(0, 1, n, endpoint=True)

#Função que calcula o valor da amplitude do sinal para cada instante de tempo amostrado
sinal = np.power(t,2)


#vizualização
plt.rcParams["figure.figsize"] = [7.50, 3.50]

plt.fill_between(t, sinal, step="pre", alpha=0.4)
plt.plot(t, sinal, drawstyle="steps")
plt.xlabel('tempo (t)')
plt.ylabel('Amplitude  x(t)')

plt.show()

# %%
import scipy.integrate as integrate

# %%
# cálculo de integral (tamanho do sinal) via método numérico
tamanho, erro  = integrate.quad(lambda t: t**2, 0, 1)
print(tamanho)
# Out:
# 0.33333333333333337

# %% [markdown]
# Entretanto, esta medida ainda é defeituosa, pois mesmo para um sinal grande $x(t)$, suas áreas positivas e negativas podem se cancelar, indicando um sinal de tamanho pequeno:

# %%
# Taxa de amostragem do sinal que iremos gerar
n = 1000

# Amostrando o sinal no tempo
t = np.linspace(-10, 10, n, endpoint=False)

#Função que calcula o valor da amplitude do sinal para cada instante de tempo amostrado
sinal = np.sin(t)

#vizualização
plt.rcParams["figure.figsize"] = [7.50, 3.50]

plt.fill_between(t, sinal, step="pre", alpha=0.4)
plt.plot(t, sinal, drawstyle="steps")
plt.xlabel('tempo (t)')
plt.ylabel('Amplitude  x(t)')

plt.show()

# %%
# cálculo de integral (tamanho do sinal) via método numérico
tamanho, erro  = integrate.quad(lambda x: np.sin(x), -10, 10)
print(tamanho)
# Out:
# 0.0

# %% [markdown]
# Esta dificuldade pode ser corrigida pela definição do tamanho do sinal como a área debaixo de $x^2(t)$ a qual é sempre positiva. Podemos chamar essa medida de **energia do sinal dissipara em um intervalo de tempo**: $$\text{Tamanho} = E =  \int_{t_1}^{t_2} x^2(t)dt\$$

# %%
#Função que calcula o valor da amplitude do sinal para cada instante de tempo amostrado
sinal = np.power(np.sin(t),2)

#vizualização
plt.rcParams["figure.figsize"] = [7.50, 3.50]

plt.fill_between(t, sinal, step="pre", alpha=0.4)
plt.plot(t, sinal, drawstyle="steps")
plt.xlabel('tempo (t)')
plt.ylabel('Amplitude  x(t)')

plt.show()

# %%
# cálculo de integral (tamanho do sinal) via método numérico
tamanho, erro  = integrate.quad(lambda x: np.power(np.sin(x),2), -10, 10)
print(tamanho)
# Out:
# 9.543527374636186

# %% [markdown]
# Essa definição pode ser generalizada para um sinal complexo $x(t)$, sendo dada por $$E = \int_{t_1}^{t_2} |x(t)|^2 dt$$

# %%
t = np.linspace(0, 0.05, 1000)

#Função com componente complexa que calcula o valor da amplitude do sinal para cada instante de tempo amostrado
sinal = np.exp(2j*np.pi*50*t)

#vizualização
plt.subplot(2,1,1)
plt.fill_between(t, sinal.real, step="pre", alpha=0.4)
plt.plot(t, sinal.real)
plt.xlabel('tempo (t)')
plt.ylabel('Real  x(t)')
plt.title(r'Parte real de $x(t)=e^{j 100 \pi t}$')

plt.subplot(2,1,2)
plt.fill_between(t, sinal.imag, step="pre", alpha=0.4)
plt.plot(t, sinal.imag )
plt.xlabel('tempo (t)')
plt.ylabel('Im  x(t)')
plt.title(r'Parte imaginária de $x(t)=e^{j 100 \pi t}$')
plt.tight_layout()
plt.show()

# %%
# cálculo de integral (tamanho do sinal) via método numérico
energia, erro  = integrate.quad(lambda t: np.power(np.abs(np.exp(2j*np.pi*50*t)),2), 0, 0.05, complex_func=True)
print(energia)
# Out:
# (0.049999999999999996+0j)

# %% [markdown]
# **A energia do sinal deve ser finita** para que seja uma medida significativa do tamanho do sinal.
#
# Uma condição necessária para que a energia seja finita é que
#
# $$x(t) → 0\;\; \text{quando}\;\; |t|→ ∞$$.
#
#
# <img src = "https://drive.google.com/uc?id=19w6YE3JDPUYkUUQryLZtnimkjlDYrX4v" width = "600">
#
# $$E = \int_{-∞}^{∞} |x(t)|^2 dt$$
#
# Caso contrário a integral da equação acima não irá convergir, como é o caso do exemplo abaixo:
#
# <img src = "https://drive.google.com/uc?id=1RDYhYVcJz6tvXDZU4l5t523iK7IlZoa6" width = "600">

# %% [markdown]
# ## Potencia de um sinal  <a class="anchor" id="section_2_4_3"></a>

# %% [markdown]
# Quando a amplitude do sinal x(t) não → 0 quando |t|→∞, a **energia do sinal é infinita** 😰.
#
# Nestes. casos, uma medida mais significativa do tamanho do sinal neste caso é a **energia média**, se ela existir.  Esta medida é chamada de **potência do sinal**.
#
# Para um sinal $x(t)$, definimos sua potência $P$ por
#
# $$P = \lim_{T \rightarrow \infty} \int_{-T/2}^{T/2} |x(t)|^2 dt$$

# %% [markdown]
# Observe que a potência $P$ do sinal é uma **média temporal do quadrado da amplitude do sinal**, ou seja, o valor médio quadrático de $x(t)$.
#
#
# Geralmente, a média de uma entidade ao longo de um grande intervalo de tempo aproximando do infinito existe se a entidade for periódica ou possuir uma regularidade estatística (para o caso de sinais não-determinísticos).
#
# A potência em um determinado intervalo de tempo é:
#
# $$P = \frac{1}{t_2-t_1}∫_{t_1}^{t_2} x^2(t) dt$$

# %% [markdown]
# ## Sinais de energia e sinais de potencia
#
#
#
# *  Um sinal de energia é um sinal em que a energia é finita (ex: sinais não periódicos)
# *  Um sinal de potência é um sinal em que a potência é finita e não nula (sinais periódicos)
# *  Ambos os sinais de energia e potência são mutuamente exclusivos, ou seja, nenhum sinal pode ser sinal de potência e sinal de energia.
# * Todos os sinais práticos têm energia finita; portanto, são sinais de energia.
# * Na prática, a geração física do sinal de potência é impossível, pois requer duração infinita e energia infinita.
# * A soma de um sinal de energia e um sinal de potência é um sinal de potência.
# * Um sinal não é um sinal de energia nem de potência se tanto a energia quanto a potência do sinal forem iguais ao infinito.
# * Um sinal cuja amplitude é constante ao longo de uma duração infinita é um sinal de potência.

# %% [markdown]
# ### Exercício:
#
# <img src = "https://drive.google.com/uc?id=1dZ5HnL4xY0iJ9x5bc_5velqzE2H5uBQr" width = "600">

# %% [markdown]
# ### Observando a energia e potência de um sinal que representa um fenômeno físico:

# %% [markdown]
# Em muitas aplicações, os sinais que consideramos estão diretamente relacionados a **quantidades físicas** e a partir deles pode-se extrair a **potência ou energia de um sistema físico**.
#
# Em circuitos elétricos, os sinais podem representar corrente ou tensão. Considere uma tensão $v(t)$ aplicada através de uma resistência $R$ e $i(t)$ é a corrente que flui através dela, conforme mostrado na figura.
#
# <img src = "https://drive.google.com/uc?id=1fa_j0QueZQWt0iFDZ4-KHP0Dtj4fiohN" width = "500">
#
# A potência instantânea na resistência $R$ é dada por:
#
# $$p(t) = v(t)i(t)$$
#
# Pela lei de Ohm:
#
#
# $$p(t) = v(t)i(t) = v(t)\frac{v(t)}{R} = \frac{v^2(t)}{R}$$
#
# Também
#
# $$𝑝(𝑡) = 𝑖(𝑡)𝑅 ∙ 𝑖(𝑡) = 𝑖^2(𝑡)𝑅$$
#
# <!-- A energia total dissipada no intervalo de tempo $t_1\le t\le t_2$ é
# $$\frac{1}{R} \int_{t_1}^{t_2}v^2(t)dt$$ -->
#
# Quando os valores da resistência $R = 1Ω$, então a potência dissipada nela é conhecida como potência normalizada. Por isso
#
# $$p(t) = v^2(t)$$
#
# Se $v(t)$ ou $i(t)$ é denotado por um sinal de tempo contínuo $x(t)$, então a potência instantânea é igual ao quadrado da amplitude do sinal, ou seja,
#
# $$p(t) = |x(t)|^2$$
#
# Portanto, a potência média ou potência normalizada de um sinal de tempo contínuo $x(t)$ é dada por,
#
# $$P=lim_{T→∞}\frac{1}{T}∫_{−(T/2)}^{T/2}|x(t)|^2dt \;\;\text{Watts}$$
#
# A energia total ou energia normalizada de um sinal de tempo contínuo é definida como
#
# $$E=lim_{T→∞}∫_{−(T/2)}^{T/2}|x(t)|^2dt \;\;\text{Joules}$$

# %% [markdown]
# # Alguns modelos de sinais úteis

# %% [markdown]
# ## Função Degrau Unitário $u(t)$
#
# Em várias de nossas discussões, os sinais começam em t = 0 (sinais causais). Tais sinais podem ser convenientemente descritos em termos da função degrau unitário $u(t)$:
#
# $$u(t) = \begin{cases} 1, & t\geq 0 \\ 0, & t< 0 \end{cases}$$

# %% [markdown]
# <img src = "https://drive.google.com/uc?id=1GdiDjLc31NEpLl2Kj1w_Fp0Mf2UDCPbh" width = "600">

# %% [markdown]
# Se quisermos um sinal que comece em $t = 0$ (de tal forma que ele possua valor nulo para $t < 0$), precisamos apenas multiplicar o sinal por $u(t)$.

# %%
# Taxa de amostragem do sinal que iremos gerar
n = 1000

# Amostrando o sinal no tempo
t = np.linspace(-10, 10, n, endpoint=False)

#Função que calcula o valor da amplitude do sinal para cada instante de tempo amostrado
sinal_ori = np.sin(t)
degrau = np.heaviside(t,0)
sinal_final = sinal_ori*degrau

#vizualização
plt.subplot(3,1,1)
plt.plot(t, sinal_ori)
plt.xlabel('tempo (t)')
plt.ylabel('x(t)')
plt.title(r'Sinal Original $x(t)=\sin{t}$')

plt.subplot(3,1,2)
plt.plot(t, degrau)
plt.xlabel('tempo (t)')
plt.ylabel('u(t)')
plt.title(r'Função degrau $u(t)$')


plt.subplot(3,1,3)
plt.plot(t, sinal_final)
plt.xlabel('tempo (t)')
plt.ylabel('u(t)')
plt.title(r'Silnal Resultante $u(t)x(t)$')

plt.tight_layout()
plt.show()

# %% [markdown]
# ##  A Função Impulso Unitário $δ(t)$
#
# A função impulso unitário $δ(t)$ é uma das mais importantes funções no estudo de sinais e sistemas.
#
# $$δ(t) = 0 \; \; t \neq 0$$
#
# $$\int_{-∞}^{∞} δ(t)dt = 1$$
#
# <img src = "https://drive.google.com/uc?id=17iddKQiyjCpZwUsxsbLRGyziYINpmJPv" width = "400">

# %% [markdown]
# A característica importante da função impulso unitário não é sua forma, mas o fato de que sua duração efetiva (largura do pulso) tende para zero enquanto que a sua área permanece unitária.

# %% [markdown]
# ### MULTIPLICAÇÃO DE UMA FUNÇÃO POR UM IMPULSO
#
# Vamos considerar o que acontece quando multiplicamos o impulso unitário $δ(t)$ por uma função $φ(t)$ que sabemos ser contínua para $t = 0$. Como o impulso possui valor não nulo apenas para $t = 0$, e o $valor φ(t)$ para $t = 0$
# é $φ(0)$, obtemos
#
# $$φ(t)δ(t) = φ(0)δ(t)$$

# %%
from scipy import signal

signal.unit_impulse(8)

imp = signal.unit_impulse(1000, 'mid')


# Taxa de amostragem do sinal que iremos gerar
n = 1000

# Amostrando o sinal no tempo
t = np.linspace(-1, 1, n, endpoint=False)
sinal_ori = 2*t**5+2
sinal_final = sinal_ori*imp

# import numpy as np
# import matplotlib.pyplot as pltplt.plot(t, imp)
plt.plot(t, sinal_ori)
plt.plot(t, sinal_final)
# plt.margins(0.1, 0.1)
# plt.xlabel('Time [samples]')
# plt.ylabel('Amplitude')
# plt.grid(True)
plt.show()

# %% [markdown]
# ## Função Exponencial $e^{st}$
#
# Outra importante função na área de sinais e sistemas é o sinal exponencial $e^{st}$, onde s é, geralmente, um número complexo, dado por
#
# $s = σ +jw$
#
# Logo,
#
# $e^{st} = e^{(σ +jw)t} = e^{σt} e^{jwt} = e^{σt}(\cos wt + j \sin wt)$

# %%
# Taxa de amostragem do sinal que iremos gerar
n = 1000

# Amostrando o sinal no tempo
t = np.linspace(-10, 10, n, endpoint=False)

sigma = 1
w = 5
sinal_exp =  np.exp((sigma + w*1j)*t)
plt.plot(np.exp(sigma*t))
plt.plot(sinal_exp)
plt.show()
